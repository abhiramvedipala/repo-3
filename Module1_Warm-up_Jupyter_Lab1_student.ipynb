# %% [markdown]
# # Module 1: Introduction
# ---

# %% [markdown]
# # Lab 1: Warm-up Jupyter

# %% [markdown]
# > * In this notebook, we will explore a real scientific dataset working with Pandas in JupyterLab.
# > * Why does this matter?
# >     1. Pandas will be your bread and butter in almost every data science project.
# >     2. JupyterLab is the most widely used IDE in data science.

# %% [markdown]
# ## Learning Objectives
#
# > By the end of this notebook, students will be able to:
# >
# > * Load tabular data with Pandas.
# > * Inspect and understand a dataset's structure.
# > * Answer basic questions using Pandas.

# %% [markdown]
# ## Dataset
#
# This lab uses **FishShapes v1**, a real research dataset published on Dryad.
#
# Each row represents **one fish specimen**, and each column contains either taxonomic information or morphological measurements.
#
# We will use this dataset throughout the first half of the course.

# %% [markdown]
# ## 1. Import packages

# %%
import pandas as pd
import numpy as np

# pd.set_option("display.max_columns",None)
# pd.set_option("display.float_format","{:.2f}".format)

# %% [markdown]
# ## 2. Load the dataset

# %%
df = pd.read_csv("FishShapes_specimensv1.csv")

# %% [markdown]
# ## 3. Inspect the dataset

# %%
df.head()
# Out:
#   SpecimenID            Tree_name      Family              Order  \
# 0     408895  Abalistes_stellatus  Balistidae  Tetraodontiformes
# 1     316729  Abalistes_stellatus  Balistidae  Tetraodontiformes
# 2     226659  Abalistes_stellatus  Balistidae  Tetraodontiformes
# 3     336887  Abbottina_rivularis  Cyprinidae      Cypriniformes
# 4     112449  Abbottina_rivularis  Cyprinidae      Cypriniformes
#
#    Total_weight  Standard_length  Max_body_depth  Max_fish_width  Head_depth  \
# 0        211.90           178.81           81.82           39.76       72.35
# 1        273.90           198.38           90.26           34.39       76.03
# 2        326.70           218.15           96.34           36.26       81.89
# 3          8.59            75.32           17.89           14.25       12.10
# 4         13.26            92.23           18.51           14.53       15.30
#
#    Lower_jaw_length  Mouth_width  Min_caudalpeduncle_depth  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16523 entries, 0 to 16522
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SpecimenID                16523 non-null  object
#  1   Tree_name                 16523 non-null  object
#  2   Family                    16523 non-null  object
#  3   Order                     16503 non-null  object
#  4   Total_weight              16426 non-null  float64
#  5   Standard_length           16515 non-null  float64
#  6   Max_body_depth            16466 non-null  float64
#  7   Max_fish_width            16473 non-null  float64
#  8   Head_depth                16505 non-null  float64
#  9   Lower_jaw_length          16500 non-null  float64
#  10  Mouth_width               16488 non-null  float64
#  11  Min_caudalpeduncle_depth  16493 non-null  float64
#  12  Min_caudalpeduncle_width  16474 non-null  float64
# dtypes: float64(9), object(4)
# ...

# %% [markdown]
# ## 4. Quick Questions

# %% [markdown]
# ### QUESTION 1
# > What are the summary statistics for the numerical variables?

# %%
df.describe()
# Out:
#        Total_weight  Standard_length  Max_body_depth  Max_fish_width  \
# count  16426.000000     16515.000000    16466.000000    16473.000000
# mean     112.891277       143.729181       38.278019       21.255959
# std      542.512133       115.686268       30.663830       15.556305
# min        0.030000        10.320000        0.980000        1.200000
# 25%        4.680000        64.645000       14.750000        9.590000
# 50%       28.800000       119.270000       30.450000       17.700000
# 75%      113.082500       190.000000       54.300000       29.080000
# max    39900.000000      1760.000000      590.000000      184.170000
#
#          Head_depth  Lower_jaw_length   Mouth_width  Min_caudalpeduncle_depth  \
# count  16505.000000      16500.000000  16488.000000              16493.000000
# mean      23.670651         17.533125     11.550270                 11.486794
# std       19.742370         15.777701     10.467619                  8.363016
# ...

# %% [markdown]
# ### QUESTION 2
# > How many unique fish species are represented?

# %%
df['Tree_name'].nunique()
# Out:
# 6112

# %% [markdown]
# ### QUESTION 3
# > What are the five most common fish families?

# %%
df['Family'].value_counts()
# Out:
# Family
# Cyprinidae          1278
# Gobiidae             641
# Cichlidae            543
# Percidae             483
# Labridae             452
#                     ...
# Chacidae               1
# Barbourisiidae         1
# Heterenchelyidae       1
# Plectrogenidae         1
# Ereuniidae             1
# Name: count, Length: 404, dtype: int64

# %% [markdown]
# ### QUESTION 4
# > How are most fish? Heavy or light?

# %%
df["Total_weight"].plot(
    kind="hist",
    bins=30,
    figsize=(6,4),
    title="Distribution of Total weight"
);

# %% [markdown]
# ---
# ## **Key Takeaways**

# %% [markdown]
# > * Pandas is used to load and manipulate tabular data.
# > * We can quickly inspect data to understand its shape and contents.
# > * `head()`, `info()`, and `describe()` provide a quick understanding of an unfamiliar dataset.
# > * Counting missing values and calculating sums per column will be frequent tasks.
# > * Using pandas to produce quick plots is a critical skill.

# %% [markdown]
# ---
# ## Students' Practice Lab 1:

# %% [markdown]
# Complete the following tasks using Pandas:
# > * How many duplicate rows are there?
# > * How many unique SpecimenID are there?
# > * Create a histogram of the Head_depth column. What similarities and differences do you observe compared with the Total_weight distribution?

# %% [markdown]
# ### Solution

# %%
# Out:
# Hello

# %%
import sys, pandas as pd, numpy as np, sklearn
print(sys.version); print(pd.__version__); print(np.__version__); print(sklearn.__version__)
# Out:
# 3.14.6 | packaged by Anaconda, Inc. | (main, Jul  9 2026, 14:30:20) [Clang 20.1.8 ]
# 3.0.3
# 2.4.6
# 1.9.0
